# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Mixed_smaller/collide-probe-6k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([1006650., 1006650., 1006650., ..., 1634580., 1635070., 1636970.])

# %%
filtered
# Out:
# array([1006653.03387145, 1006650.9061464 , 1006648.8191979 , ...,
#        1634553.07761767, 1635003.33504667, 1635451.61243306])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([ 1668, 13854, 22586]),
#  {'prominences': array([1.30778181e+02, 7.49601509e+05, 6.09325757e+05]),
#   'left_bases': array([    0,     0, 19644]),
#   'right_bases': array([ 1819, 24300, 24300]),
#   'widths': array([ 684.85274284, 8793.61730174, 2562.59161852]),
#   'width_heights': array([-1006562.85835836,  -631852.27925566, -1137016.13724942]),
#   'left_ips': array([ 1075.93563274,  7295.3428766 , 20903.8501763 ]),
#   'right_ips': array([ 1760.78837557, 16088.96017834, 23466.44179483])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
