# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Al2O3_stoichmatch/collide-probe-5k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([ 737197.,  737195.,  737193., ..., 1514840., 1514940., 1514970.])

# %%
filtered
# Out:
# array([ 737195.36227491,  737193.62126321,  737191.93223819, ...,
#        1514397.98270768, 1514461.18916109, 1514521.15305879])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([  813,  7353, 15410, 20387, 26963]),
#  {'prominences': array([1.12552068e+02, 8.29465528e+02, 5.73938886e+05, 1.77651062e+04,
#          5.09304285e+05]),
#   'left_bases': array([    0,  2082,  2082, 19904, 23309]),
#   'right_bases': array([ 2082,  7448, 29800, 29800, 29800]),
#   'widths': array([ 237.78801368,   91.63037975, 9467.30937801,  451.2758769 ,
#          3534.77185991]),
#   'width_heights': array([-737139.086241  , -528416.81240097, -450310.21054923,
#          -584784.10211435, -842102.26427522]),
#   'left_ips': array([  739.085043  ,  7311.74835975,  9119.46238516, 20140.56297328,
#          24653.20955312]),
#   'right_ips': array([  976.87305669,  7403.3787395 , 18586.77176317, 20591.83885018,
#          28187.98141303])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plot.png")
plt.show()
