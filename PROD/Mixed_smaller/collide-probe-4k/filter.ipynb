# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Mixed_smaller/collide-probe-4k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([457127., 457126., 457125., ..., 720452., 720376., 720304.])

# %%
filtered
# Out:
# array([457123.22507896, 457122.97458705, 457122.70292159, ...,
#        720144.39388076, 720096.11361004, 720048.70301485])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([ 2381,  7560, 16475, 28079, 32950]),
#  {'prominences': array([1.20638902e+02, 1.07027836e+02, 3.36464455e+05, 1.70358560e+05,
#          2.02974940e+02]),
#   'left_bases': array([    0,  2753,  2753, 24872, 32932]),
#   'right_bases': array([ 2753,  7605, 33019, 33019, 33019]),
#   'widths': array([ 1181.09531461,    42.95536278, 10788.58936181,  3444.05504754,
#             21.67654446]),
#   'width_heights': array([-457062.90562772, -333460.95419418, -288946.72619148,
#          -479430.61270409, -910069.14798021]),
#   'left_ips': array([ 1444.31917435,  7538.08773082,  9064.62782996, 26580.41727454,
#          32941.33677896]),
#   'right_ips': array([ 2625.41448897,  7581.0430936 , 19853.21719177, 30024.47232208,
#          32963.01332342])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plt.png")
plt.show()
