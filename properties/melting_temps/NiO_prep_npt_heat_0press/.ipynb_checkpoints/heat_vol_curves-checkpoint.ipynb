# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
temp = np.loadtxt("./temp.dat")
vol = np.loadtxt("./vol.dat")

# %%
plt.plot(temp[:,1])

# %%
plt.plot(vol[:,1])

# %%
fig,ax = plt.subplots()
ax.plot(temp[:,1], color='red')
ax2 = ax.twinx()
ax2.plot(vol[:,1], color='blue')
ax.axhline(1955, color='black', label='experimental')
fig.legend(["temp", "experimental mt", "volume"])
ax.set_xlabel("step")
ax.set_ylabel("temp (K)")
ax2.set_ylabel("volume $(A^3)$")
plt.savefig("melting_curve.png")

# %%
fig,ax = plt.subplots()
ax.scatter(temp[:,1], vol[:,1], s=0.01)
ax.set_ylabel("temp (K)")
ax.set_xlabel("volume $(A^3)$")
ax.axvline(1955, color='black', label='experimental')
plt.savefig("melt_trace.png")
