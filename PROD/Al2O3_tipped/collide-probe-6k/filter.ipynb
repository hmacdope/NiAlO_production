# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Al2O3_tipped/collide-probe-6k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([1034140., 1034140., 1034140., ...,  852141.,  851582.,  851024.])

# %%
filtered
# Out:
# array([1034140.50355836, 1034139.80678212, 1034139.10368115, ...,
#         852057.28930147,  851630.70997295,  851205.61762772])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([ 1203,  6004,  9324, 14108]),
#  {'prominences': array([1.83636512e+02, 7.31389325e+02, 8.90434896e+03, 7.85370778e+05]),
#   'left_bases': array([   0, 1704, 1704, 1704]),
#   'right_bases': array([ 1704,  6118, 10269, 20175]),
#   'widths': array([1514.89351259,   85.73577188,  191.9613733 , 8726.12487809]),
#   'width_heights': array([-1034048.6853026 ,  -761188.94109395,  -502195.78660715,
#           -641518.57575181]),
#   'left_ips': array([ 106.97674984, 5967.88641076, 9218.13684524, 7706.70654781]),
#   'right_ips': array([ 1621.87026243,  6053.62218264,  9410.09821854, 16432.8314259 ])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plot.png")
plt.show()
