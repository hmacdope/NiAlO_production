# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Al2O3_tipped_one2one/collide-probe-4k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([412867., 412866., 412865., ..., 921548., 921966., 922422.])

# %%
filtered
# Out:
# array([412870.07541037, 412869.03440654, 412868.00936285, ...,
#        921303.88442984, 921727.1923178 , 922152.03017048])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([ 1539,  6105, 11711, 18587, 24699, 32694, 38456, 40877]),
#  {'prominences': array([7.89637605e+01, 5.07179142e+01, 4.84038160e+02, 3.04776315e+05,
#          5.07609289e+03, 2.86020990e+05, 1.00042359e+02, 2.43242697e+05]),
#   'left_bases': array([ 1230,  2282,  2282,  2282, 23992, 29311, 38437, 38938]),
#   'right_bases': array([ 2282,  6143, 11796, 43300, 29311, 43300, 38938, 43300]),
#   'widths': array([  577.07059019,    29.27116277,    95.42666877, 12588.54743452,
#            662.86881336,  4470.91939333,    20.66750202,  1812.92192469]),
#   'width_heights': array([-412841.99025361, -315375.04038866, -208480.36611195,
#          -260651.47232743, -347233.67521159, -385076.49959034,
#          -747414.23968188, -630044.91079083]),
#   'left_ips': array([ 1319.78934686,  6092.27366262, 11656.76528348,  9915.05688928,
#          24345.17465596, 30920.15000853, 38446.51691455, 39986.49227978]),
#   'right_ips': array([ 1896.85993704,  6121.54482539, 11752.19195225, 22503.6043238 ,
#          25008.04346933, 35391.06940185, 38467.18441658, 41799.41420447])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plot.png")
plt.show()
