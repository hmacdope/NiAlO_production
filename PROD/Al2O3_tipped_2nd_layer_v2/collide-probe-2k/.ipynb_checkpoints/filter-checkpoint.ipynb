# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Al2O3_tipped_2nd_layer_v2/collide-probe-2k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([130666., 130666., 130666., ..., 214868., 214871., 214872.])

# %%
filtered
# Out:
# array([130663.96230477, 130663.93608163, 130663.91128033, ...,
#        214831.4336654 , 214824.69107982, 214817.307374  ])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([  878,  2965,  5075, 22437, 41258, 43383]),
#  {'prominences': array([7.26229022e+01, 4.05781573e+01, 6.62432473e+00, 1.00827108e+05,
#          1.33681205e+03, 9.95422825e+04]),
#   'left_bases': array([  564,  2276,  4978,  4978, 35710, 35710]),
#   'right_bases': array([ 4978,  4978,  5110, 49986, 41812, 49986]),
#   'widths': array([  258.03301085,   234.76772056,    40.86296448, 15201.57793779,
#            584.35225896,  7620.45976805]),
#   'width_heights': array([-130640.76061975, -130652.86565126, -131129.94462335,
#           -80752.56474115,  -85054.28641882, -128388.31829502]),
#   'left_ips': array([  768.49583652,  2882.21821446,  5050.52347125, 13232.05509152,
#          40890.99321891, 38560.82552618]),
#   'right_ips': array([ 1026.52884736,  3116.98593502,  5091.38643573, 28433.63302931,
#          41475.34547788, 46181.28529423])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plot.png")
plt.show()
