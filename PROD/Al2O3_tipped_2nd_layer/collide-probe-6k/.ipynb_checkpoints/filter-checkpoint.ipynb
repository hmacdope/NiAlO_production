# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Al2O3_tipped_2nd_layer/collide-probe-6k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([1042710., 1042710., 1042710., ..., 1411350., 1411720., 1412080.])

# %%
filtered
# Out:
# array([1042714.29889116, 1042713.90692518, 1042713.50394848, ...,
#        1411053.8216018 , 1411506.23676558, 1411956.89807352])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([ 1196, 13791, 22690]),
#  {'prominences': array([1.04384455e+02, 8.14669401e+05, 6.43478659e+05]),
#   'left_bases': array([    0,  1457, 19703]),
#   'right_bases': array([ 1457, 19703, 23866]),
#   'widths': array([ 456.37221086, 8641.0686703 , 2198.26423197]),
#   'width_heights': array([-1042662.10666347,  -635898.54239797, -1090217.56833599]),
#   'left_ips': array([  874.7787305 ,  7326.55424336, 21112.19536938]),
#   'right_ips': array([ 1331.15094136, 15967.62291367, 23310.45960136])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plot.png")
plt.show()
