# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Al2O3_tipped_2nd_layer/collide-probe-4k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([473067., 473068., 473068., ..., 711374., 711252., 711136.])

# %%
filtered
# Out:
# array([473071.77607183, 473071.71485828, 473071.64643102, ...,
#        710912.40109154, 710743.12042498, 710573.45438997])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([ 1444, 12358, 16656, 21697, 29512]),
#  {'prominences': array([1.10695703e+02, 8.21138803e+02, 3.73160764e+05, 4.91617842e+03,
#          2.32994168e+05]),
#   'left_bases': array([    0,  2176,  2176, 21287, 24844]),
#   'right_bases': array([ 2176, 12450, 33218, 33218, 33218]),
#   'widths': array([  232.28979063,    77.31528729, 10940.65748927,   359.95779842,
#           3730.70190583]),
#   'width_heights': array([-473016.42822049, -215941.76522059, -287102.0194913 ,
#          -383770.85809124, -512578.19719389]),
#   'left_ips': array([ 1318.08680078, 12322.86439379,  8933.60876227, 21502.58033822,
#          26724.33035483]),
#   'right_ips': array([ 1550.37659141, 12400.17968108, 19874.26625154, 21862.53813664,
#          30455.03226067])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)

plt.savefig("min_ke_plot.png")
plt.show()
