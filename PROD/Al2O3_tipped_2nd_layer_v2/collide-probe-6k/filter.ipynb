# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Al2O3_tipped_2nd_layer_v2/collide-probe-6k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([1037800., 1037790., 1037790., ..., 1430520., 1430920., 1431330.])

# %%
filtered
# Out:
# array([1037794.32394049, 1037793.29058027, 1037792.27442372, ...,
#        1430751.22349083, 1431196.0591725 , 1431639.50304607])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([  877, 10202, 13965, 22763]),
#  {'prominences': array([1.46024391e+02, 3.84432392e+02, 8.09767172e+05, 6.65234052e+05]),
#   'left_bases': array([    0,  1684,  1684, 19812]),
#   'right_bases': array([ 1684, 10249, 19812, 24000]),
#   'widths': array([ 799.4684032 ,   60.94784112, 8562.85183484, 2228.98607696]),
#   'width_heights': array([-1037721.31174516,  -485520.87013356,  -633398.44827582,
#          -1099022.47711127]),
#   'left_ips': array([  627.45944347, 10167.1991862 ,  7537.69108284, 21189.87710842]),
#   'right_ips': array([ 1426.92784668, 10228.14702732, 16100.54291767, 23418.86318538])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plot.png")
plt.show()
