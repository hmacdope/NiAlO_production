# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Reproduce_Original_one2one/collide-probe-6k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:25000,0]
ke_vals = ke[:25000,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([ 902295.,  902295.,  902294., ..., 1209130., 1208910., 1208690.])

# %%
filtered
# Out:
# array([ 902295.96672091,  902295.07705502,  902294.19541739, ...,
#        1209157.53509611, 1208934.5679641 , 1208710.93956608])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([  228,  7400, 11671, 16080, 21472]),
#  {'prominences': array([1.28711025e+02, 7.00040816e+01, 1.11418560e+04, 7.42313770e+05,
#          1.27788660e+05]),
#   'left_bases': array([    0,  1624,  1624,  1624, 20375]),
#   'right_bases': array([ 1624,  7429, 12516, 24208, 24208]),
#   'widths': array([ 276.40598473,   26.30172967,  953.5753583 , 9892.41512147,
#          1088.53126073]),
#   'width_heights': array([-902231.6112086 , -638772.19181274, -402814.25821429,
#          -531739.14217138, -794987.67148861]),
#   'left_ips': array([  115.67616199,  7388.72240954, 11184.38908013,  9365.57979836,
#          20896.78255417]),
#   'right_ips': array([  392.08214672,  7415.02413921, 12137.96443843, 19257.99491983,
#          21985.3138149 ])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plot.png")
plt.show()
