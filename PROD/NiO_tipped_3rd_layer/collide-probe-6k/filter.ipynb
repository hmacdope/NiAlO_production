# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/NiO_tipped_3rd_layer/collide-probe-6k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([946635., 946635., 946634., ..., 948547., 948944., 949381.])

# %%
filtered
# Out:
# array([946643.51289323, 946640.70011705, 946637.93536649, ...,
#        948499.31020763, 948754.64822761, 948999.09154509])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([ 1352,  3465,  7888, 13815, 22420]),
#  {'prominences': array([3.41742344e+02, 3.35244836e+03, 1.02133655e+03, 7.30327964e+05,
#          1.80949148e+05]),
#   'left_bases': array([    0,  1636,  1636,  1636, 19499]),
#   'right_bases': array([ 1636,  3579,  7952, 19499, 22938]),
#   'widths': array([1040.27447357,   96.56765935,   60.97601846, 8606.73272925,
#           796.87784131]),
#   'width_heights': array([-946472.64172123, -826649.59155614, -566020.902488  ,
#          -582641.79811526, -858524.51775034]),
#   'left_ips': array([  483.92361335,  3421.34578836,  7858.83612846,  7404.40174412,
#          21936.14081313]),
#   'right_ips': array([ 1524.19808693,  3517.91344771,  7919.81214692, 16011.13447337,
#          22733.01865444])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
