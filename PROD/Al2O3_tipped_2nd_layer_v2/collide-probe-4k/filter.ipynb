# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Al2O3_tipped_2nd_layer_v2/collide-probe-4k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([470851., 470851., 470851., ..., 737350., 737168., 736992.])

# %%
filtered
# Out:
# array([470849.63371516, 470849.26566878, 470848.89944416, ...,
#        737164.28019423, 736857.44859553, 736547.45246021])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([  883, 12748, 17016, 21909, 29629]),
#  {'prominences': array([1.01631260e+02, 8.78061255e+01, 3.74477246e+05, 2.34354583e+03,
#          2.44147093e+05]),
#   'left_bases': array([    0,  2521,  2521, 21575, 25047]),
#   'right_bases': array([ 2521, 12797, 33306, 33306, 33306]),
#   'widths': array([  732.72630564,    49.45656749, 10916.26014175,   314.21640928,
#           3692.64418666]),
#   'width_heights': array([-470798.81808507, -212987.28757653, -284131.78583779,
#          -381345.14728242, -513013.96353992]),
#   'left_ips': array([  658.71183067, 12727.61991991,  9299.50822326, 21746.62035547,
#          26936.4290244 ]),
#   'right_ips': array([ 1391.43813631, 12777.0764874 , 20215.76836502, 22060.83676475,
#          30629.07321106])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)

plt.savefig("min_ke_plot.png")
plt.show()
