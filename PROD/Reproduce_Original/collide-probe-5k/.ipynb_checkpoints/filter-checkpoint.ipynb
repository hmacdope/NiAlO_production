# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Reproduce_Original/collide-probe-5k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([  719995.,   719994.,   719992., ..., 21506200., 21515400.,
#        21526900.])

# %%
filtered
# Out:
# array([  720008.09715863,   720004.60270767,   720001.22535746, ...,
#        21423238.80882436, 21460928.6064218 , 21498555.77805044])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([  306,  7373, 11054, 15518, 20542, 26822, 31298, 34072, 37288,
#         39489]),
#  {'prominences': array([1.07315073e+02, 2.29355754e+03, 1.01998163e+04, 5.71752493e+05,
#          2.04137722e+04, 5.65870020e+05, 7.11999359e+05, 6.98953627e+05,
#          5.09304157e+05, 2.83673101e+05]),
#   'left_bases': array([    0,  2313,  2313,  2313, 20021, 23382, 29575, 32961, 36769,
#          39313]),
#   'right_bases': array([ 2313,  7483, 12183, 41900, 23382, 41900, 41900, 41900, 41900,
#          41900]),
#   'widths': array([ 369.6621693 ,  100.14098423,  787.54178072, 9260.1171538 ,
#           484.90595403, 3408.49238329, 1783.34041024, 1179.40931097,
#           484.24721339,  196.29709076]),
#   'width_heights': array([ -719954.43962224,  -517455.9904907 ,  -333239.79143008,
#           -434434.57737546,  -564238.64263356,  -798671.38137456,
#          -1136360.67102043, -1473745.18691479, -2340465.51272513,
#          -3975456.94038121]),
#   'left_ips': array([2.26941286e+01, 7.32550702e+03, 1.09013919e+04, 9.37420817e+03,
#          2.02714323e+04, 2.47569831e+04, 3.03512770e+04, 3.34024460e+04,
#          3.70097679e+04, 3.94020110e+04]),
#   'right_ips': array([  392.35629792,  7425.64799936, 11688.93364939, 18634.32532638,
#          20756.33823102, 28165.47546429, 32134.61741905, 34581.85533477,
#          37494.01509114, 39598.30804756])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plot.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 plt.plot(axis, ke_vals)
#       2 plt.plot(axis, filtered)
#       3 for i in peaks[0]:
#
# NameError: name 'plt' is not defined
