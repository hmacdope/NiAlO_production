# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Ni_surface/Ni_6_12000/collide-probe-6k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([1034340., 1034330., 1034340., 1034380., 1034570., 1034660.,
#        1034650., 1034640., 1034630., 1034620., 1034610., 1034620.,
#        1034620., 1034620., 1034610., 1034610., 1034610., 1034610.,
#        1034600., 1034590., 1034590., 1034580., 1034570., 1034560.,
#        1034550., 1034540., 1034530., 1034530., 1034710., 1035370.,
#        1035370., 1035390., 1035410., 1035310., 1035450., 1035560.,
#        1035560., 1035560., 1035550., 1035530., 1035540., 1035540.,
#        1035530., 1035530., 1035510., 1035510., 1035570., 1035580.,
#        1035590., 1035600., 1035600., 1035590., 1035590., 1035580.,
#        1035570., 1035520., 1035620., 1035630., 1035620., 1035620.,
#        1035620., 1035620., 1035620., 1035620., 1035620., 1035620.,
#        1035610., 1035610., 1035610., 1035620., 1035620., 1035620.,
#        1035610., 1035600., 1036350., 1040200., 1040180., 1040180.,
#        1105290., 1303670., 1690060., 3189480., 3189490., 3189480.,
#        3189470., 3189480., 3189480., 2085000., 2085000., 2084980.,
#        2084990., 2084990., 2084920., 2084830., 2084880., 2084960.,
#        2084980., 1495980., 1495510., 1497070., 1497370.])

# %%
filtered
# Out:
# array([1158612.11743445, 1144849.2412526 , 1131511.50332636,
#        1118602.18161336, 1106124.55407124, 1094081.89865763,
#        1082477.49333016, 1071314.61604647, 1060596.5447642 ,
#        1050326.55744098, 1040507.93203444, 1031143.94650222,
#        1022237.87880195, 1013793.00689126, 1005812.6087278 ,
#         998299.96226919,  991258.34547308,  984691.03629708,
#         978601.31269884,  972992.452636  ,  967867.73406618,
#         963230.43494703,  959083.83323617,  955431.20689124,
#         952275.83386988,  949620.99212971,  947469.95962838,
#         945826.01432351,  944692.43417275,  944072.49713372,
#         943969.48116407,  944386.66422142,  945327.3242634 ,
#         946794.73924767,  948792.18713184,  951322.94587355,
#         954390.29343044,  957997.50776015,  962147.8668203 ,
#         966844.64856852,  972091.13096247,  977890.59195976,
#         984246.30951804,  991161.56159493,  998639.62614808,
#        1006683.78113511, 1015297.30451366, 1024483.47424137,
#        1034245.56827587, 1044586.86457479, 1072348.26017409,
#        1078908.00687122, 1092431.09559248, 1106488.05328347,
#        1121073.77018471, 1136183.1365367 , 1151811.04257999,
#        1167952.37855508, 1184602.03470249, 1201754.90126275,
#        1219405.86847638, 1237549.82658389, 1256181.66582581,
#        1275296.27644266, 1294888.54867495, 1314953.37276322,
#        1335485.63894797, 1356480.23746974, 1377932.05856903,
#        1399835.99248637, 1422186.92946229, 1444979.75973729,
#        1468209.37355191, 1491870.66114665, 1515958.51276205,
#        1540467.81863863, 1565393.46901689, 1590730.35413737,
#        1616473.36424058, 1642617.38956705, 1669157.32035729,
#        1696088.04685182, 1723404.45929117, 1751101.44791586,
#        1779173.9029664 , 1807616.71468332, 1836424.77330714,
#        1865592.96907837, 1895116.19223754, 1924989.33302517,
#        1955207.28168178, 1985764.92844788, 2016657.16356401,
#        2047878.87727067, 2079424.9598084 , 2111290.30141771,
#        2143469.79233911, 2175958.32281314, 2208750.78308031,
#        2241842.06338114, 2275227.05395616])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([30]),
#  {'prominences': array([214642.63627038]),
#   'left_bases': array([0]),
#   'right_bases': array([100]),
#   'widths': array([40.33537336]),
#   'width_heights': array([-1051290.79929926]),
#   'left_ips': array([8.90611071]),
#   'right_ips': array([49.24148407])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plot.png")
plt.show()
