# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Al2O3_tipped/collide-probe-5k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([ 723372.,  723371.,  723370., ..., 1446880., 1446930., 1446970.])

# %%
filtered
# Out:
# array([ 723369.9768621 ,  723369.60548551,  723369.22301672, ...,
#        1446746.06083547, 1446762.9124461 , 1446775.56055889])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([ 1201, 10308, 15386, 19644, 26244]),
#  {'prominences': array([1.52455386e+02, 9.32790131e+03, 5.49491502e+05, 2.10691677e+03,
#          5.07169955e+05]),
#   'left_bases': array([    0,  2044,  2044, 19505, 22700]),
#   'right_bases': array([ 2044, 11424, 28900, 22700, 28900]),
#   'widths': array([1828.93601051,  744.796378  , 9725.34347428,  200.88325689,
#          3419.21493531]),
#   'width_heights': array([-723293.74916935, -350023.91531663, -448686.48471639,
#          -564417.05591688, -803302.71550722]),
#   'left_ips': array([  133.24898553, 10157.58428163,  8548.01419916, 19577.91976945,
#          23956.34501507]),
#   'right_ips': array([ 1962.18499604, 10902.38065963, 18273.35767344, 19778.80302634,
#          27375.55995038])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plot.png")
plt.show()
