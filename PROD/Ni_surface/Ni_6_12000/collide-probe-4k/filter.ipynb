# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Ni_surface/Ni_6_12000/collide-probe-4k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([ 469134.,  469132.,  469137.,  469179.,  469376.,  469468.,
#         469451.,  469441.,  469436.,  469426.,  469419.,  469434.,
#         469428.,  469428.,  469428.,  469427.,  469426.,  469423.,
#         469417.,  469410.,  469405.,  469399.,  469392.,  469383.,
#         469373.,  469367.,  469361.,  469361.,  469541.,  470204.,
#         470199.,  470216.,  470237.,  470139.,  470286.,  470392.,
#         470393.,  470395.,  470386.,  470373.,  470377.,  470381.,
#         470373.,  470371.,  470357.,  470353.,  470417.,  470427.,
#         470440.,  470444.,  470448.,  470437.,  470438.,  470432.,
#         470422.,  470376.,  470470.,  470489.,  470478.,  470476.,
#         470478.,  470479.,  470476.,  470480.,  470481.,  470483.,
#         470477.,  470477.,  470479.,  470482.,  470486.,  470484.,
#         470477.,  470467.,  471223.,  475068.,  475053.,  475053.,
#         540162.,  738538., 1124870., 2624060., 2624070., 2624070.,
#        2624060., 2624060., 2624070., 2624050.,  932298.,  932277.,
#         932562.,  932841.,  932771.,  932685.,  932734.,  932820.,
#         932838.,  932834.,  933613.,  934725.,  935045.])

# %%
filtered
# Out:
# array([ 629699.39603757,  609452.46732   ,  590094.46239668,
#         571615.73048729,  554006.62081154,  537257.48258914,
#         521358.66503977,  506300.51738315,  492073.38883897,
#         478667.62862693,  466073.58596673,  454281.61007808,
#         443282.05018067,  433065.25549421,  423621.57523839,
#         414941.35863291,  407014.95489748,  399832.71325179,
#         393384.98291555,  387662.11310846,  382654.45305021,
#         378352.35196051,  374746.15905905,  371826.22356555,
#         369582.89469969,  368006.52168118,  367087.45372972,
#         366816.04006501,  367182.62990675,  368177.57247464,
#         369791.21698838,  372013.91266767,  374836.00873221,
#         378247.8544017 ,  382239.79889585,  386802.19143435,
#         391925.3812369 ,  397599.7175232 ,  403815.54951296,
#         410563.22642587,  417833.09748163,  425615.51189995,
#         433900.81890053,  442679.36770306,  451941.50752725,
#         461677.58759279,  471877.95711939,  482532.96532674,
#         493632.96143456,  505168.29466253,  528004.41668668,
#         534724.9958244 ,  548452.19015571,  562548.16747209,
#         576997.80966631,  591785.9986311 ,  606897.6162592 ,
#         622317.54444337,  638030.66507634,  654021.86005086,
#         670276.01125968,  686778.00059553,  703512.70995118,
#         720465.02121935,  737619.81629279,  754961.97706425,
#         772476.38542647,  790147.9232722 ,  807961.47249418,
#         825901.91498516,  843954.13263788,  862103.00734508,
#         880333.42099952,  898630.25549392,  916978.39272105,
#         935362.71457364,  953768.10294443,  972179.43972618,
#         990581.60681162, 1008959.48609351, 1027297.95946458,
#        1045581.90881758, 1063796.21604526, 1081925.76304036,
#        1099955.43169562, 1117870.10390379, 1135654.66155761,
#        1153293.98654983, 1170772.96077319, 1188076.46612044,
#        1205189.38448432, 1222096.59775757, 1238782.98783295,
#        1255233.43660319, 1271432.82596104, 1287366.03779924,
#        1303017.95401054, 1318373.45648768, 1333417.42712341,
#        1348134.74781048, 1362510.30044162])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([27]),
#  {'prominences': array([262883.35597256]),
#   'left_bases': array([0]),
#   'right_bases': array([100]),
#   'widths': array([40.83560663]),
#   'width_heights': array([-498257.71805129]),
#   'left_ips': array([7.56531431]),
#   'right_ips': array([48.40092094])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plot.png")
plt.show()
