# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Ni_surface/Ni_3_6000/collide-probe-6k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([1029100., 1029100., 1029100., ..., 1284360., 1284140., 1283920.])

# %%
filtered
# Out:
# array([1029101.29308175, 1029099.35258501, 1029097.4102997 , ...,
#        1283942.20279827, 1283695.88532473, 1283448.20169069])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([  142,  2211,  4325,  6798, 11816, 15734, 17997, 22232]),
#  {'prominences': array([1.83292842e+02, 8.68387455e+01, 2.39021909e+01, 1.24054610e+02,
#          3.66847122e+02, 4.00931853e+03, 8.18542810e+05, 2.79187309e+04]),
#   'left_bases': array([    0,  2060,  4224,  3632,  3632,  3632,  3632, 21496]),
#   'right_bases': array([ 3632,  3632,  4417,  6840, 11853, 16245, 23662, 23662]),
#   'widths': array([ 218.36187458,  173.50811179,   80.46426432,   40.15268694,
#            31.60648412,  396.40677655, 8686.96466657,  609.11637857]),
#   'width_heights': array([-1029009.64666093, -1029170.43539918, -1029299.48188777,
#           -906303.48913567,  -578219.12103092,  -322459.64517107,
#           -620089.70985895, -1070098.00633255]),
#   'left_ips': array([   48.24558785,  2131.37201824,  4275.45955048,  6780.61166218,
#          11802.71374684, 15619.76271982, 11329.36696018, 21830.88635482]),
#   'right_ips': array([  266.60746243,  2304.88013004,  4355.92381481,  6820.76434912,
#          11834.32023096, 16016.16949637, 20016.33162674, 22440.00273339])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plot.png")
plt.show()
