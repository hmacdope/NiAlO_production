# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Al2O3_stoichmatch/collide-probe-6k

# %%
ke = np.loadtxt("ke.dat")

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([1053740., 1053730., 1053730., ..., 2034200., 2035010., 2035810.])

# %%
filtered
# Out:
# array([1053734.17302701, 1053731.90401747, 1053729.70491848, ...,
#        2034311.27135792, 2035347.36819343, 2036380.26712204])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([  872,  6500, 13983, 18197, 23773]),
#  {'prominences': array([1.34073927e+02, 1.82083287e+03, 8.06303141e+05, 3.96783938e+03,
#          8.39714212e+05]),
#   'left_bases': array([    0,  1723,  1723, 17975, 20722]),
#   'right_bases': array([ 1723,  6599, 25800, 20722, 25800]),
#   'widths': array([ 642.58092539,   85.76652668, 8449.77861318,  244.89019744,
#          2905.27888932]),
#   'width_heights': array([-1053667.13606333,  -756863.407473  ,  -650639.59380253,
#           -871402.24253753, -1225536.03718039]),
#   'left_ips': array([  523.13755508,  6459.23321336,  8183.4115118 , 18071.0440902 ,
#          21915.6165866 ]),
#   'right_ips': array([ 1165.71848047,  6544.99974005, 16633.19012499, 18315.93428764,
#          24820.89547592])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
plt.savefig("min_ke_plot.png")
plt.show()
