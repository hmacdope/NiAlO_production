# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
ke = np.loadtxt("ke.dat")

# %%
# !pwd
# Out:
# /store/Terry_project_production/PROD/Reproduce_Original_NiAl/collide-probe-6k

# %%
axis = ke[:,0]
ke_vals = ke[:,1]

# %%
filtered = scipy.signal.savgol_filter(ke_vals, 100, 3 )

# %%
ke_vals
# Out:
# array([1201400., 1201400., 1201390., ..., 1009800., 1009810., 1009830.])

# %%
filtered
# Out:
# array([1201397.87241463, 1201395.90830274, 1201393.96654772, ...,
#        1009812.30282689, 1009794.16822283, 1009780.20358833])

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)

# %%
peaks = scipy.signal.find_peaks(-filtered, width=20, distance=2000)

# %%
plt.plot(axis, -filtered)

# %%
peaks
# Out:
# (array([  434,  6311, 10141, 15418, 17436]),
#  {'prominences': array([1.39363771e+02, 1.85752459e+03, 8.70851302e+03, 8.34436575e+05,
#          1.75390256e+04]),
#   'left_bases': array([    0,  1865,  1865,  1865, 16948]),
#   'right_bases': array([ 1865,  6461, 10789, 23756, 23756]),
#   'widths': array([  983.40926276,   139.02021615,   326.99020512, 11239.40804675,
#            578.15575726]),
#   'width_heights': array([-1201328.19052905,  -913275.36363147,  -657772.03012006,
#           -785850.25605794,  -431167.33021309]),
#   'left_ips': array([  319.68129025,  6251.14287591,  9922.56220534,  8398.70517986,
#          17159.84058625]),
#   'right_ips': array([ 1303.09055301,  6390.16309205, 10249.55241046, 19638.11322661,
#          17737.99634351])})

# %%
plt.plot(axis, ke_vals)
plt.plot(axis, filtered)
for i in peaks[0]:
    plt.axvline(i)
